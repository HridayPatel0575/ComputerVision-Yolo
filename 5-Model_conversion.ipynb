# %% [markdown]
# Target: iOS / macOS<br/>
# OS: macOS / Linux

# %%
from ultralytics import YOLO

model = YOLO("C:\\Users\\Admin\\Desktop\\YOLO_Projects\\best_ppe.pt")
model.export(
    format="coreml",
    imgsz=640,     
    nms=True,      
    half=True      
)

# %%
model = YOLO("best_ppe.pt")

model.export(
    format="tf",
    imgsz=640,
    nms=True
)

# %% [markdown]
# Target: Android / Web<br/>
# OS: Windows

# %%
model.export(
    format="tflite",
    imgsz=640,
    int8=False   
)

# %% [markdown]
# Target: NVIDIA GPU<br/>
# OS: Linux ONLY

# %%
model.export(
    format="engine",
    imgsz=640,
    half=True,
    device=0
)

# %% [markdown]
# Target: Intel CPU / iGPU <br/>
# OS: Windows

# %%
model.export(
    format="openvino",
    imgsz=640,
    half=True
)
