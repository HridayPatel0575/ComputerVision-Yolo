# %%
import os
import cv2
from ultralytics import YOLO

# %%
video__path = os.path.join('.','data','C:\\Users\\Admin\\Desktop\\YOLO_Projects\\ppe-2-1.mp4')

cap = cv2.VideoCapture(video__path)
ret,frame = cap.read()

model = YOLO('yolov8n.pt').to('cuda')

while ret:

    results = model(frame)
    
    for result in results:
        detection = []
        for r in result.boxes.data.tolist():
            x1 , x2 , y1 , y2 ,score , class_id = r
            x1 , x2 , y1 , y2 = int(x1),int(y1),int(x2),int(y2)
            detection.append([x1,y1,x2,y2,score])
    cv2.imshow('frame',frame)
    cv2.waitKey(25)

    ret,frame = cap.read()



cap.release()
cv2.destroyAllWindows()

# %%
video_path = r"C:\Users\Admin\Desktop\YOLO_Projects\ppe-2-1.mp4"

cap = cv2.VideoCapture(video_path)

model = YOLO("yolov8n.pt").to("cuda")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model.track(
        frame,
        persist=True,
        tracker="bytetrack.yaml",
        device=0
    )

    # Draw boxes + IDs
    annotated_frame = results[0].plot()

    cv2.imshow("YOLOv8 + ByteTrack", annotated_frame)

    if cv2.waitKey(25) & 0xFF == 27:  # ESC
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
#
# 0: 384x640 2 persons, 69.7ms
# Speed: 3.2ms preprocess, 69.7ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.5ms
# Speed: 1.4ms preprocess, 7.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.4ms
# Speed: 1.4ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.5ms
# Speed: 1.4ms preprocess, 7.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.2ms
# Speed: 1.3ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.9ms
# ...

# %%
# !pip uninstall tracker -y
# !pip install deep-sort-realtime
# Out:
# Found existing installation: tracker 0.1.1
# Uninstalling tracker-0.1.1:
#   Successfully uninstalled tracker-0.1.1
# ...
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/8.4 MB 6.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.1/8.4 MB 5.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.4 MB 5.8 MB/s eta 0:00:01
#    ------------------ --------------------- 3.9/8.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.7/8.4 MB 4.7 MB/s eta 0:00:01
#    -------------------------- ------------- 5.5/8.4 MB 4.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.3/8.4 MB 4.6 MB/s eta 0:00:01
#    --------------------------------- ------ 7.1/8.4 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.6/8.4 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 4.2 MB/s  0:00:01
# ...

# %%
import os
import cv2
import numpy as np
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

video_path = r"C:\Users\Admin\Desktop\YOLO_Projects\ppe-2-1.mp4"

cap = cv2.VideoCapture(video_path)

model = YOLO("yolov8n.pt").to("cuda")

tracker = DeepSort(
    max_age=30,
    n_init=3,
    max_iou_distance=0.7,
)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame, conf=0.4, device=0)[0]

    detections = []
    for box in results.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = float(box.conf[0])
        cls = int(box.cls[0])

        detections.append(([x1, y1, x2 - x1, y2 - y1], conf, cls))

    tracks = tracker.update_tracks(detections, frame=frame)

    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        l, t, r, b = map(int, track.to_ltrb())

        cv2.rectangle(frame, (l, t), (r, b), (0, 255, 0), 2)
        cv2.putText(
            frame,
            f"ID {track_id}",
            (l, t - 10),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.6,
            (0, 255, 0),
            2,
        )

    cv2.imshow("YOLOv8 + DeepSORT", frame)

    if cv2.waitKey(25) & 0xFF == 27:  # ESC
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 persons, 22.1ms
# Speed: 3.0ms preprocess, 22.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.3ms
# Speed: 1.4ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.6ms
# Speed: 1.5ms preprocess, 7.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 10.2ms
# Speed: 1.5ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 7.8ms
# ...
