# %%
# !pip uninstall ultralytics -y
# !pip install ultralytics

# %%
from ultralytics import YOLO
import cv2

model = YOLO("yolov8l.pt")

results = model("C:/Users/Admin/Downloads/gettyimages-1220169562-612x612.jpg")
img = results[0].plot()

cv2.imshow("YOLOv8 Result", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8l.pt to 'yolov8l.pt': 100% ━━━━━━━━━━━━ 83.7MB 1.0MB/s 1:24/s 1:24<0.0sss
#
# image 1/1 C:\Users\Admin\Downloads\gettyimages-1220169562-612x612.jpg: 448x640 6 persons, 1 bus, 4 backpacks, 1 handbag, 729.6ms
# Speed: 2.6ms preprocess, 729.6ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
